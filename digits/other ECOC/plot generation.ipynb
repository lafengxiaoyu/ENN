# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0,4,10,15,20,45,75,100, 150,200,250, 300, 511]
y = [0.1,0.51,0.655,0.724,0.75,0.78,0.84,0.8522, 0.8667, 0.8778, 0.8756, 0.8889,0.881]

plt.plot(x,y)
plt.show()

# %%
x = np.array([0,4,10,45,100, 250,511])
y = np.array([0.1, 0.51, 0.6555,0.78054,0.82834,0.85905,0.88057])
std = np.array([0.02, 0.002254504556, 0.001905378333, 0.0009757071111, 0.000694876, 0.0005539657143, 0.0001459201111])
# std 1 需要改
plt.xlabel('Number of Base Learners ($N_\mathrm{T}$)')
plt.ylabel('Accuracy')
plt.plot(x, y, label = "ECOC-45bit", linewidth=1)
plt.fill_between(x, y - std* 4.417/np.sqrt(10), y + std* 4.417/np.sqrt(10), alpha=.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate


x = np.array([0,4,10,45,100, 250,511])
y = np.array([0.1, 0.51, 0.6555,0.78054,0.82834,0.85905,0.88057])
std = np.array([0.02, 0.002254504556, 0.001905378333, 0.0009757071111, 0.000694876, 0.0005539657143, 0.0001459201111])

tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 511, 1)
ynew = interpolate.splev(xnew, tck, der=0)

# tck = interpolate.splrep(x, std, s=0)
# stdnew = interpolate.splev(xnew, tck, der=0)

#plt.figure()
plt.xlabel('Number of Base Learners ($N_\mathrm{T}$)')
plt.ylabel('Accuracy')
plt.plot(x, y, 'x')
plt.plot(xnew, ynew, label = "ECOC")
#plt.legend(loc = 'lower right')
#plt.axis([-0.05, 6.33, -1.05, 1.05])
#plt.fill_between(x[1:], y[1:] - std[1:]* 144.417/np.sqrt(10), y[1:] + std[1:]* 144.417/np.sqrt(10), alpha=.5)


plt.grid()
#plt.savefig("numberofbaselearners.eps")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate


x = np.array([0,4,10,45,100, 250,511])
y = np.array([0.1, 0.51, 0.6555,0.78054,0.82834,0.85905,0.88057])
std = np.array([0.02, 0.002254504556, 0.001905378333, 0.0009757071111, 0.000694876, 0.0005539657143, 0.0001459201111])

tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 511, 1)
ynew = interpolate.splev(xnew, tck, der=0)

# tck = interpolate.splrep(x, std, s=0)
# stdnew = interpolate.splev(xnew, tck, der=0)

#plt.figure()
plt.xlabel('Number of Base Learners ($N_\mathrm{T}$)')
plt.ylabel('Accuracy')
plt.plot(x, y, 'x')
plt.plot(xnew, ynew, label = "ECOC")
#plt.legend(loc = 'lower right')
#plt.axis([-0.05, 6.33, -1.05, 1.05])
#plt.fill_between(x[1:], y[1:] - std[1:]* 144.417/np.sqrt(10), y[1:] + std[1:]* 144.417/np.sqrt(10), alpha=.5)


plt.grid()
#plt.savefig("numberofbaselearners.eps")
plt.show()

# %%
plt.plot(std)
plt.show()

# %%
a = [[0.4722,0.5167,0.5611,0.4333,0.4889,0.5223,0.5167,0.4889,0.6056,0.5],
[0.6833,0.6833,0.6778,0.6667,0.6889,0.6555,0.6944,0.65,0.5889,0.5667],
[0.8,0.7833,0.7333,0.7778,0.7611,0.7722,0.75,0.8166,0.7722,0.8389],
[0.8722,0.8389,0.8167,0.8444,0.8222,0.8389,0.8167,0.8056,0.85,0.7778],
[0.8444,0.8667,0.8334,0.9,0.8334,0.8556,0.8833,0.8556,0.85,0.8334],
[0.8778,0.8778,0.9056,0.8778,0.8667,0.8833,0.8722,0.8833,0.8945,0.8667]]

# %%
labels = '4','10','45','100', '250', '511'#图例
plt.boxplot(a, labels = labels, notch = False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate


x = np.array([0,4,10,45,100, 250,511])
y = np.array([0.1, 0.51, 0.6555,0.78054,0.82834,0.85905,0.88057])
std = np.array([0.02, 0.002254504556, 0.001905378333, 0.0009757071111, 0.000694876, 0.0005539657143, 0.0001459201111])

tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 511, 1)
ynew = interpolate.splev(xnew, tck, der=0)

# tck = interpolate.splrep(x, std, s=0)
# stdnew = interpolate.splev(xnew, tck, der=0)

#plt.figure()
plt.xlabel('Number of Base Learners ($N_\mathrm{T}$)')
plt.ylabel('Accuracy')
plt.plot(np.log(x+1), y, 'x')
plt.plot(np.log(xnew+1), ynew, label = "ECOC")
#plt.legend(loc = 'lower right')
#plt.axis([-0.05, 6.33, -1.05, 1.05])
#plt.fill_between(x[1:], y[1:] - std[1:]* 144.417/np.sqrt(10), y[1:] + std[1:]* 144.417/np.sqrt(10), alpha=.5)


plt.grid()
#plt.savefig("numberofbaselearners.eps")
plt.show()
