 0.7458256029684601,
 0.8274582560296846,
 0.7841682127396413,
 0.8670377241805813,
 0.7866419294990723,
 0.87569573283859,
 0.8713667285095856,
 0.9579468150896723,
 0.8126159554730983,
 0.8682745825602969,
 0.8701298701298701,
 0.9653679653679653,
 0.8274582560296846,
 0.9059987631416203,
 0.9325912183055041]

# %%
import pandas as pd
from collections import defaultdict
import warnings
import visualize
import neat
import multiprocessing
import os
import matplotlib.pyplot as plt

import numpy as np

# %%
import random

te = []
cc = []
acc = []
num_classifiers = []
error_list = []

necoc = 4

for iii in range(10000):
    while True:
        number_codes = []
        for i in range(2**(10-1), 2**10-1):
            for j in bin(i).split('b')[1]:
                number_codes.append(int(j))
        number_codes = np.array(number_codes).reshape(2**9 - 1,10).T     

        slice = random.sample(range(2**9-1), necoc)
        #slice = range(31)

        number_codes = number_codes[:,slice].tolist()

        classes = []
        for i in range(necoc):
            code_list = np.array(number_codes).T[i]
            classes.append(np.where(code_list==1)[0].tolist())

        matrix_errors = []

        for i in range(9):
            for j in range(i+1,10):
                matrix_errors.append(necoc - np.sum(np.array(number_codes[i]) == np.array(number_codes[j])))
        min_error = np.min(matrix_errors)
        if min_error != 0:
            #print("min row distanse: {}".format(min_error))
            #print(number_codes)
            break
    #print("We choose classifers: {}".format(slice))
    #print("classes are: {}".format(classes))
    #np.array(number_codes)
    #print("accuracy of each classifier:{}".format([winner_list1[i] for i in slice]))
    rou = min_error/necoc
    epsilon = np.mean([1 - winner_list1[i] for i in slice])
    te.append(2*epsilon/rou)
    cc.append(classes)
    acc.append([winner_list1[i] for i in slice])
    num_classifiers.append(slice)
    error_list.append(min_error)
    #print("p:{}, e:{}: training error:{}".format(rou, epsilon, 2*epsilon/rou))

# %%
print("minimum te: {}".format(min(te)))
print("class1 are:{}".format(cc[te.index(min(te))]))
print("number of classifiers are:{}".format(num_classifiers[te.index(min(te))]))
print("acc of classifiers are:{}".format(acc[te.index(min(te))]))
print("mean of these classifiers are:{}".format(np.mean(acc[te.index(min(te))])))
print("min error: {}".format(error_list[te.index(min(te))]))
# Out:
# minimum te: 1.100803957946815
# class1 are:[[0, 1, 4, 5, 6, 9], [0, 3, 4, 5, 7, 8, 9], [0, 1, 2, 7, 8, 9], [0, 4, 6, 8]]
# number of classifiers are:[313, 119, 391, 42]
# acc of classifiers are:[0.8460111317254174, 0.8658008658008658, 0.849721706864564, 0.8880643166357453]
# mean of these classifiers are:0.8623995052566481
# min error: 1

# %%
print("maximum te: {}".format(max(te)))
print("class1 are:{}".format(cc[te.index(max(te))]))
print("number of classifiers are:{}".format(num_classifiers[te.index(max(te))]))
print("acc of classifiers are:{}".format(acc[te.index(max(te))]))
print("mean of these classifiers are:{}".format(np.mean(acc[te.index(max(te))])))
print("min error: {}".format(error_list[te.index(max(te))]))
# Out:
# maximum te: 2.2127396413110696
# class1 are:[[0, 1, 2, 4, 5, 9], [0, 2, 5, 7, 8], [0, 2, 6, 7, 9], [0, 1, 3, 5, 7]]
# number of classifiers are:[433, 150, 141, 340]
# acc of classifiers are:[0.7291280148423006, 0.7594310451453309, 0.7031539888682746, 0.7019171304885591]
# mean of these classifiers are:0.7234075448361162
# min error: 1

# %%
plt.hist(np.mean(acc, axis = 1),bins = 50)
plt.show()

# %%
import random

te = []
cc = []
acc = []
num_classifiers = []
error_list = []

necoc = 4

for iii in range(10000):
    while True:
        number_codes = []
        for i in range(2**(10-1), 2**10-1):
            for j in bin(i).split('b')[1]:
                number_codes.append(int(j))
        number_codes = np.array(number_codes).reshape(2**9 - 1,10).T     

        slice = random.sample(range(2**9-1), necoc)
        #slice = range(31)

        number_codes = number_codes[:,slice].tolist()

        classes = []
        for i in range(necoc):
            code_list = np.array(number_codes).T[i]
            classes.append(np.where(code_list==1)[0].tolist())

        matrix_errors = []

        for i in range(9):
            for j in range(i+1,10):
                matrix_errors.append(necoc - np.sum(np.array(number_codes[i]) == np.array(number_codes[j])))
        min_error = np.min(matrix_errors)
        if min_error != 0:
            #print("min row distanse: {}".format(min_error))
            #print(number_codes)
            break
    #print("We choose classifers: {}".format(slice))
    #print("classes are: {}".format(classes))
    #np.array(number_codes)
    #print("accuracy of each classifier:{}".format([winner_list1[i] for i in slice]))
    rou = min_error/necoc
    epsilon = np.mean([1 - winner_list1[i] for i in slice])
    te.append(2*epsilon/rou)
    cc.append(classes)
    acc.append([winner_list1[i] for i in slice])
    num_classifiers.append(slice)
    error_list.append(min_error)
    #print("p:{}, e:{}: training error:{}".format(rou, epsilon, 2*epsilon/rou))

# %%
print("minimum te: {}".format(min(te)))
print("class1 are:{}".format(cc[te.index(min(te))]))
print("number of classifiers are:{}".format(num_classifiers[te.index(min(te))]))
print("acc of classifiers are:{}".format(acc[te.index(min(te))]))
print("mean of these classifiers are:{}".format(np.mean(acc[te.index(min(te))])))
print("min error: {}".format(error_list[te.index(min(te))]))
# Out:
# minimum te: 1.08843537414966
# class1 are:[[0, 1, 2, 3, 5, 7, 8, 9], [0, 1, 4, 7, 9], [0, 4, 5, 6, 8, 9], [0, 1, 2, 4, 6, 8]]
# number of classifiers are:[471, 293, 59, 426]
# acc of classifiers are:[0.9332096474953617, 0.8317872603586889, 0.8478664192949907, 0.8429189857761287]
# mean of these classifiers are:0.8639455782312925
# min error: 1

# %%
print("maximum te: {}".format(max(te)))
print("class1 are:{}".format(cc[te.index(max(te))]))
print("number of classifiers are:{}".format(num_classifiers[te.index(max(te))]))
print("acc of classifiers are:{}".format(acc[te.index(max(te))]))
print("mean of these classifiers are:{}".format(np.mean(acc[te.index(max(te))])))
print("min error: {}".format(error_list[te.index(max(te))]))
# Out:
# maximum te: 2.170686456400742
# class1 are:[[0, 1, 2, 5, 6, 8], [0, 2, 3, 4, 8], [0, 1, 3, 6, 7], [0, 1, 2, 4, 5, 9]]
# number of classifiers are:[410, 226, 332, 433]
# acc of classifiers are:[0.7674706246134818, 0.7464440321583179, 0.6716141001855288, 0.7291280148423006]
# mean of these classifiers are:0.7286641929499073
# min error: 1

# %%
plt.hist(np.array(winner_list2 )- np.array(winner_list1),bins = 50)
plt.show()

# %%
np.sum(np.abs((np.array(winner_list2 )- np.array(winner_list1)))<0.02)/len(np.array(winner_list2))
# Out:
# 0.6986301369863014
