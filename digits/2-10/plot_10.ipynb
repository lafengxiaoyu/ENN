# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
a10 = [0.21274]*2 + [0.26902]*(14-1) + [0.27149]*(16-14) + [0.31045]*(37-16) + [0.3222]*(42-37)+ [0.34385]*(47-42)+ [0.37477]*(104-47)+ [0.38219]*(159-104)+ [0.38528]*(160-159)+ [0.42362]*(339-160)+ [0.42548 ]*(354-339)+ [0.43537]*(753-354)+ [0.44527]*(838-753)+ [0.44712]*(1055-838)+ [0.45207]*(1499-1055)

# %%
a = np.load("fitness.npy")
b = np.load("avg.npy")
c = np.load("stdev.npy")

# %%
a1 = np.load("fitness1.npy")
b1 = np.load("avg1.npy")
c1 = np.load("stdev1.npy")

# %%
a2 = np.load("fitness2.npy")
b2 = np.load("avg2.npy")
c2 = np.load("stdev2.npy")

# %%
a3 = np.load("fitness3.npy")

# %%
a0 = [0.96875, 0.98125, 0.99375] + [1.00000] * 1497

# %%
plt.ylim((0.2, 1.05))
plt.xlabel('Generations')
plt.ylabel('Accuracy')
plt.plot(a0,label = '2')
for i in range(4):
    plt.plot(a[i],label = str(i+3))
plt.plot(a3[0],label = '7') 
plt.plot(a1[0],label = '8')    
plt.plot(a2[0],label = '9')
plt.plot(a10,label = '10')
plt.grid()
plt.legend()
#plt.savefig("digitsmulti.eps")
plt.show()
